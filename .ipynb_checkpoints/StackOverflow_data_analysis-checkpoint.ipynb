# %%
# !pip install opendatasets

# %%
import opendatasets as od

# %%
od.download('stackoverflow-developer-survey-2020')
# Out:
# Using downloaded and verified file: .\stackoverflow-developer-survey-2020\survey_results_public.csv
# Using downloaded and verified file: .\stackoverflow-developer-survey-2020\survey_results_schema.csv
# Using downloaded and verified file: .\stackoverflow-developer-survey-2020\README.txt

# %%
import os

# %%
os.listdir('.')
# Out:
# ['.git',
#  '.ipynb_checkpoints',
#  'stackoverflow-developer-survey-2020',
#  'StackOverflow_data_analysis.ipynb']

# %%
os.listdir('./stackoverflow-developer-survey-2020')
# Out:
# ['README.txt', 'survey_results_public.csv', 'survey_results_schema.csv']

# %%
import pandas as pd

# %%
survey_raw_df = pd.read_csv('stackoverflow-developer-survey-2020/survey_results_public.csv')

# %%
survey_raw_df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1                     I am a developer by profession      Yes
# 1               2                     I am a developer by profession       No
# 2               3                        I code primarily as a hobby      Yes
# 3               4                     I am a developer by profession      Yes
# 4               5  I used to be a developer by profession, but no...      Yes
# ...           ...                                                ...      ...
# 64456       64858                                                NaN      Yes
# 64457       64867                                                NaN      Yes
# 64458       64898                                                NaN      Yes
# 64459       64925                                                NaN      Yes
# 64460       65112                                                NaN      Yes
#
# ...

# %%
survey_raw_df.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'Age', 'Age1stCode', 'CompFreq',
#        'CompTotal', 'ConvertedComp', 'Country', 'CurrencyDesc',
#        'CurrencySymbol', 'DatabaseDesireNextYear', 'DatabaseWorkedWith',
#        'DevType', 'EdLevel', 'Employment', 'Ethnicity', 'Gender', 'JobFactors',
#        'JobSat', 'JobSeek', 'LanguageDesireNextYear', 'LanguageWorkedWith',
#        'MiscTechDesireNextYear', 'MiscTechWorkedWith',
#        'NEWCollabToolsDesireNextYear', 'NEWCollabToolsWorkedWith', 'NEWDevOps',
#        'NEWDevOpsImpt', 'NEWEdImpt', 'NEWJobHunt', 'NEWJobHuntResearch',
#        'NEWLearn', 'NEWOffTopic', 'NEWOnboardGood', 'NEWOtherComms',
#        'NEWOvertime', 'NEWPurchaseResearch', 'NEWPurpleLink', 'NEWSOSites',
#        'NEWStuck', 'OpSys', 'OrgSize', 'PlatformDesireNextYear',
#        'PlatformWorkedWith', 'PurchaseWhat', 'Sexuality', 'SOAccount',
#        'SOComm', 'SOPartFreq', 'SOVisitFreq', 'SurveyEase', 'SurveyLength',
# ...

# %%
schema_fname = 'stackoverflow-developer-survey-2020/survey_results_schema.csv'

# %%
schema_raw = pd.read_csv(schema_fname)

# %%
schema_raw
# Out:
#                 Column                                       QuestionText
# 0           Respondent  Randomized respondent ID number (not in order ...
# 1           MainBranch  Which of the following options best describes ...
# 2             Hobbyist                            Do you code as a hobby?
# 3                  Age  What is your age (in years)? If you prefer not...
# 4           Age1stCode  At what age did you write your first line of c...
# ..                 ...                                                ...
# 56  WebframeWorkedWith  Which web frameworks have you done extensive d...
# 57       WelcomeChange  Compared to last year, how welcome do you feel...
# 58         WorkWeekHrs  On average, how many hours per week do you wor...
# 59           YearsCode  Including any education, how many years have y...
# 60        YearsCodePro  NOT including education, how many years have y...
#
# [61 rows x 2 columns]

# %%
schema_raw = pd.read_csv(schema_fname , index_col = 'Column')

# %%
schema_raw
# Out:
#                                                          QuestionText
# Column
# Respondent          Randomized respondent ID number (not in order ...
# MainBranch          Which of the following options best describes ...
# Hobbyist                                      Do you code as a hobby?
# Age                 What is your age (in years)? If you prefer not...
# Age1stCode          At what age did you write your first line of c...
# ...                                                               ...
# WebframeWorkedWith  Which web frameworks have you done extensive d...
# WelcomeChange       Compared to last year, how welcome do you feel...
# WorkWeekHrs         On average, how many hours per week do you wor...
# YearsCode           Including any education, how many years have y...
# YearsCodePro        NOT including education, how many years have y...
#
# [61 rows x 1 columns]

# %%
schema_raw = pd.read_csv(schema_fname , index_col = 'Column').QuestionText

# %%
schema_raw
# Out:
# Column
# Respondent            Randomized respondent ID number (not in order ...
# MainBranch            Which of the following options best describes ...
# Hobbyist                                        Do you code as a hobby?
# Age                   What is your age (in years)? If you prefer not...
# Age1stCode            At what age did you write your first line of c...
#                                             ...
# WebframeWorkedWith    Which web frameworks have you done extensive d...
# WelcomeChange         Compared to last year, how welcome do you feel...
# WorkWeekHrs           On average, how many hours per week do you wor...
# YearsCode             Including any education, how many years have y...
# YearsCodePro          NOT including education, how many years have y...
# Name: QuestionText, Length: 61, dtype: object

# %%
schema_raw['Age']
# Out:
# 'What is your age (in years)? If you prefer not to answer, you may leave this question blank.'

# %%
type(schema_raw)
# Out:
# pandas.core.series.Series

# %%
schema_raw['YearsCodePro']
# Out:
# 'NOT including education, how many years have you coded professionally (as a part of your work)?'

# %% [markdown]
# ## Data Preparation & Cleaning

# %%
selected_columns = [
    # Demographics
    'Country',
    'Age',
    'Gender',
    'EdLevel',
    'UndergradMajor',
    # Programming experience
    'Hobbyist',
    'Age1stCode',
    'YearsCode',
    'YearsCodePro',
    'LanguageWorkedWith',
    'LanguageDesireNextYear',
    'NEWLearn',
    'NEWStuck',
    # Employment
    'Employment',
    'DevType',
    'WorkWeekHrs',
    'JobSat',
    'JobFactors',
    'NEWOvertime',
    'NEWEdImpt'
]

# %%
selected_columns
# Out:
# ['Country',
#  'Age',
#  'Gender',
#  'EdLevel',
#  'UndergradMajor',
#  'Hobbyist',
#  'Age1stCode',
#  'YearsCode',
#  'YearsCodePro',
#  'LanguageWorkedWith',
#  'LanguageDesireNextYear',
#  'NEWLearn',
#  'NEWStuck',
#  'Employment',
#  'DevType',
#  'WorkWeekHrs',
#  'JobSat',
#  'JobFactors',
#  'NEWOvertime',
#  'NEWEdImpt']

# %%
len(selected_columns)
# Out:
# 20

# %%
survey_raw_df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1                     I am a developer by profession      Yes
# 1               2                     I am a developer by profession       No
# 2               3                        I code primarily as a hobby      Yes
# 3               4                     I am a developer by profession      Yes
# 4               5  I used to be a developer by profession, but no...      Yes
# ...           ...                                                ...      ...
# 64456       64858                                                NaN      Yes
# 64457       64867                                                NaN      Yes
# 64458       64898                                                NaN      Yes
# 64459       64925                                                NaN      Yes
# 64460       65112                                                NaN      Yes
#
# ...

# %%
survey_df = survey_raw_df[selected_columns].copy()

# %%
survey_df
# Out:
#                   Country   Age Gender  \
# 0                 Germany   NaN    Man
# 1          United Kingdom   NaN    NaN
# 2      Russian Federation   NaN    NaN
# 3                 Albania  25.0    Man
# 4           United States  31.0    Man
# ...                   ...   ...    ...
# 64456       United States   NaN    NaN
# 64457             Morocco   NaN    NaN
# 64458            Viet Nam   NaN    NaN
# 64459              Poland   NaN    NaN
# 64460               Spain   NaN    NaN
#
#                                                EdLevel  \
# 0      Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 1         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2                                                  NaN
# 3      Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 4         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# ...                                                ...
# 64456  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# ...

# %%
schema = schema_raw[selected_columns]

# %%
schema
# Out:
# Column
# Country                                                  Where do you live?
# Age                       What is your age (in years)? If you prefer not...
# Gender                    Which of the following describe you, if any? P...
# EdLevel                   Which of the following best describes the high...
# UndergradMajor                        What was your primary field of study?
# Hobbyist                                            Do you code as a hobby?
# Age1stCode                At what age did you write your first line of c...
# YearsCode                 Including any education, how many years have y...
# YearsCodePro              NOT including education, how many years have y...
# LanguageWorkedWith        Which programming, scripting, and markup langu...
# LanguageDesireNextYear    Which programming, scripting, and markup langu...
# NEWLearn                  How frequently do you learn a new language or ...
# ...

# %%
survey_df.shape
# Out:
# (64461, 20)

# %%
survey_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64461 entries, 0 to 64460
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Country                 64072 non-null  object
#  1   Age                     45446 non-null  float64
#  2   Gender                  50557 non-null  object
#  3   EdLevel                 57431 non-null  object
#  4   UndergradMajor          50995 non-null  object
#  5   Hobbyist                64416 non-null  object
#  6   Age1stCode              57900 non-null  object
#  7   YearsCode               57684 non-null  object
#  8   YearsCodePro            46349 non-null  object
#  9   LanguageWorkedWith      57378 non-null  object
#  10  LanguageDesireNextYear  54113 non-null  object
#  11  NEWLearn                56156 non-null  object
#  12  NEWStuck                54983 non-null  object
#  13  Employment              63854 non-null  object
# ...

# %%
schema.EdLevel
# Out:
# 'Which of the following best describes the highest level of formal education that you’ve completed?'

# %%
schema.UndergradMajor
# Out:
# 'What was your primary field of study?'

# %%
schema.Age1stCode
# Out:
# 'At what age did you write your first line of code or program? (e.g., webpage, Hello World, Scratch project)'

# %%
schema.YearsCode
# Out:
# 'Including any education, how many years have you been coding in total?'

# %%
schema.YearsCodePro
# Out:
# 'NOT including education, how many years have you coded professionally (as a part of your work)?'

# %%
schema.NEWLearn
# Out:
# 'How frequently do you learn a new language or framework?'

# %%
schema.NEWStuck
# Out:
# 'What do you do when you get stuck on a problem? Select all that apply.'

# %%
schema.DevType
# Out:
# 'Which of the following describe you? Please select all that apply.'

# %%
schema.NEWOvertime
# Out:
# 'How often do you work overtime or beyond the formal time expectation of your job?'

# %%
schema.NEWEdImpt
# Out:
# 'How important is a formal education, such as a university degree in computer science, to your career?'

# %%
survey_df
# Out:
#                   Country   Age Gender  \
# 0                 Germany   NaN    Man
# 1          United Kingdom   NaN    NaN
# 2      Russian Federation   NaN    NaN
# 3                 Albania  25.0    Man
# 4           United States  31.0    Man
# ...                   ...   ...    ...
# 64456       United States   NaN    NaN
# 64457             Morocco   NaN    NaN
# 64458            Viet Nam   NaN    NaN
# 64459              Poland   NaN    NaN
# 64460               Spain   NaN    NaN
#
#                                                EdLevel  \
# 0      Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 1         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2                                                  NaN
# 3      Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 4         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# ...                                                ...
# 64456  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# ...

# %%
survey_df['Age1stCode'] = pd.to_numeric(survey_df.Age1stCode , errors='coerce')
survey_df['YearsCode'] = pd.to_numeric(survey_df.YearsCode , errors='coerce')
survey_df['YearsCodePro'] = pd.to_numeric(survey_df.YearsCodePro , errors='coerce')

# %%
survey_df
# Out:
#                   Country   Age Gender  \
# 0                 Germany   NaN    Man
# 1          United Kingdom   NaN    NaN
# 2      Russian Federation   NaN    NaN
# 3                 Albania  25.0    Man
# 4           United States  31.0    Man
# ...                   ...   ...    ...
# 64456       United States   NaN    NaN
# 64457             Morocco   NaN    NaN
# 64458            Viet Nam   NaN    NaN
# 64459              Poland   NaN    NaN
# 64460               Spain   NaN    NaN
#
#                                                EdLevel  \
# 0      Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 1         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2                                                  NaN
# 3      Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 4         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# ...                                                ...
# 64456  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# ...

# %%
survey_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64461 entries, 0 to 64460
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Country                 64072 non-null  object
#  1   Age                     45446 non-null  float64
#  2   Gender                  50557 non-null  object
#  3   EdLevel                 57431 non-null  object
#  4   UndergradMajor          50995 non-null  object
#  5   Hobbyist                64416 non-null  object
#  6   Age1stCode              57473 non-null  float64
#  7   YearsCode               56784 non-null  float64
#  8   YearsCodePro            44133 non-null  float64
#  9   LanguageWorkedWith      57378 non-null  object
#  10  LanguageDesireNextYear  54113 non-null  object
#  11  NEWLearn                56156 non-null  object
#  12  NEWStuck                54983 non-null  object
#  13  Employment              63854 non-null  object
# ...

# %%
survey_df.describe()
# Out:
#                 Age    Age1stCode     YearsCode  YearsCodePro   WorkWeekHrs
# count  45446.000000  57473.000000  56784.000000  44133.000000  41151.000000
# mean      30.834111     15.476572     12.782051      8.869667     40.782174
# std        9.585392      5.114081      9.490657      7.759961     17.816383
# min        1.000000      5.000000      1.000000      1.000000      1.000000
# 25%       24.000000     12.000000      6.000000      3.000000     40.000000
# 50%       29.000000     15.000000     10.000000      6.000000     40.000000
# 75%       35.000000     18.000000     17.000000     12.000000     44.000000
# max      279.000000     85.000000     50.000000     50.000000    475.000000

# %%
survey_df.drop(survey_df[survey_df.Age > 100].index , inplace=True)

# %%
survey_df
# Out:
#                   Country   Age Gender  \
# 0                 Germany   NaN    Man
# 1          United Kingdom   NaN    NaN
# 2      Russian Federation   NaN    NaN
# 3                 Albania  25.0    Man
# 4           United States  31.0    Man
# ...                   ...   ...    ...
# 64456       United States   NaN    NaN
# 64457             Morocco   NaN    NaN
# 64458            Viet Nam   NaN    NaN
# 64459              Poland   NaN    NaN
# 64460               Spain   NaN    NaN
#
#                                                EdLevel  \
# 0      Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 1         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2                                                  NaN
# 3      Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 4         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# ...                                                ...
# 64456  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# ...

# %%
survey_df.drop(survey_df[survey_df.Age < 10].index , inplace=True)

# %%
survey_df
# Out:
#                   Country   Age Gender  \
# 0                 Germany   NaN    Man
# 1          United Kingdom   NaN    NaN
# 2      Russian Federation   NaN    NaN
# 3                 Albania  25.0    Man
# 4           United States  31.0    Man
# ...                   ...   ...    ...
# 64456       United States   NaN    NaN
# 64457             Morocco   NaN    NaN
# 64458            Viet Nam   NaN    NaN
# 64459              Poland   NaN    NaN
# 64460               Spain   NaN    NaN
#
#                                                EdLevel  \
# 0      Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 1         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2                                                  NaN
# 3      Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 4         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# ...                                                ...
# 64456  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# ...

# %%
survey_df[survey_df.Age < 10]
# Out:
# Empty DataFrame
# Columns: [Country, Age, Gender, EdLevel, UndergradMajor, Hobbyist, Age1stCode, YearsCode, YearsCodePro, LanguageWorkedWith, LanguageDesireNextYear, NEWLearn, NEWStuck, Employment, DevType, WorkWeekHrs, JobSat, JobFactors, NEWOvertime, NEWEdImpt]
# Index: []

# %%
survey_df[survey_df.Age > 100]
# Out:
# Empty DataFrame
# Columns: [Country, Age, Gender, EdLevel, UndergradMajor, Hobbyist, Age1stCode, YearsCode, YearsCodePro, LanguageWorkedWith, LanguageDesireNextYear, NEWLearn, NEWStuck, Employment, DevType, WorkWeekHrs, JobSat, JobFactors, NEWOvertime, NEWEdImpt]
# Index: []

# %%
survey_df.describe()
# Out:
#                 Age    Age1stCode     YearsCode  YearsCodePro   WorkWeekHrs
# count  45436.000000  57467.000000  56776.000000  44128.000000  41147.000000
# mean      30.834294     15.476273     12.783130      8.870354     40.782153
# std        9.506982      5.113997      9.490771      7.760095     17.816102
# min       10.000000      5.000000      1.000000      1.000000      1.000000
# 25%       24.000000     12.000000      6.000000      3.000000     40.000000
# 50%       29.000000     15.000000     10.000000      6.000000     40.000000
# 75%       35.000000     18.000000     17.000000     12.000000     44.000000
# max       99.000000     85.000000     50.000000     50.000000    475.000000

# %%
survey_df.drop(survey_df[survey_df.WorkWeekHrs > 140].index , inplace=True)

# %%
survey_df.describe()
# Out:
#                 Age    Age1stCode     YearsCode  YearsCodePro   WorkWeekHrs
# count  45319.000000  57326.000000  56636.000000  43993.000000  41002.000000
# mean      30.832322     15.475317     12.783883      8.873003     40.024395
# std        9.505965      5.114952      9.494519      7.762089     10.630010
# min       10.000000      5.000000      1.000000      1.000000      1.000000
# 25%       24.000000     12.000000      6.000000      3.000000     40.000000
# 50%       29.000000     15.000000     10.000000      6.000000     40.000000
# 75%       35.000000     18.000000     17.000000     12.000000     43.000000
# max       99.000000     85.000000     50.000000     50.000000    140.000000

# %%
survey_df
# Out:
#                   Country   Age Gender  \
# 0                 Germany   NaN    Man
# 1          United Kingdom   NaN    NaN
# 2      Russian Federation   NaN    NaN
# 3                 Albania  25.0    Man
# 4           United States  31.0    Man
# ...                   ...   ...    ...
# 64456       United States   NaN    NaN
# 64457             Morocco   NaN    NaN
# 64458            Viet Nam   NaN    NaN
# 64459              Poland   NaN    NaN
# 64460               Spain   NaN    NaN
#
#                                                EdLevel  \
# 0      Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 1         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2                                                  NaN
# 3      Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 4         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# ...                                                ...
# 64456  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# ...

# %%
survey_df.Gender.unique()
# Out:
# array(['Man', nan, 'Woman',
#        'Man;Non-binary, genderqueer, or gender non-conforming',
#        'Non-binary, genderqueer, or gender non-conforming',
#        'Woman;Non-binary, genderqueer, or gender non-conforming',
#        'Woman;Man;Non-binary, genderqueer, or gender non-conforming',
#        'Woman;Man'], dtype=object)

# %%
survey_df.Gender.value_counts()
# Out:
# Gender
# Man                                                            45895
# Woman                                                           3835
# Non-binary, genderqueer, or gender non-conforming                385
# Man;Non-binary, genderqueer, or gender non-conforming            121
# Woman;Non-binary, genderqueer, or gender non-conforming           92
# Woman;Man                                                         73
# Woman;Man;Non-binary, genderqueer, or gender non-conforming       25
# Name: count, dtype: int64

# %%
import numpy as np

# %%
survey_df.where(~(survey_df.Gender.str.contains(';', na=False)), np.nan, inplace=True)

# %%
survey_df
# Out:
#                   Country   Age Gender  \
# 0                 Germany   NaN    Man
# 1          United Kingdom   NaN    NaN
# 2      Russian Federation   NaN    NaN
# 3                 Albania  25.0    Man
# 4           United States  31.0    Man
# ...                   ...   ...    ...
# 64456       United States   NaN    NaN
# 64457             Morocco   NaN    NaN
# 64458            Viet Nam   NaN    NaN
# 64459              Poland   NaN    NaN
# 64460               Spain   NaN    NaN
#
#                                                EdLevel  \
# 0      Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 1         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2                                                  NaN
# 3      Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 4         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# ...                                                ...
# 64456  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# ...

# %%
survey_df.Gender.value_counts()
# Out:
# Gender
# Man                                                  45895
# Woman                                                 3835
# Non-binary, genderqueer, or gender non-conforming      385
# Name: count, dtype: int64

# %%
survey_df.sample(10)
# Out:
#                     Country   Age Gender  \
# 29984                Israel  29.0    Man
# 1682          United States  20.0    Man
# 58083                 India  23.0    Man
# 1834          United States  24.0    Man
# 51835             Australia  26.0    Man
# 45466                Mexico  28.0    Man
# 14342                 Italy  37.0    Man
# 42874         United States   NaN    NaN
# 2757          United States  35.0    Man
# 19373  United Arab Emirates  36.0    Man
#
#                                                  EdLevel  \
# 29984  Some college/university study without earning ...
# 1682                           Primary/elementary school
# 58083       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 1834        Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 51835       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 45466       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 14342         Other doctoral degree (Ph.D., Ed.D., etc.)
# ...

# %% [markdown]
# ## Exploratory Analysis and Visualization

# %%
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sns.set_style('darkgrid')
matplotlib.rcParams['font.size'] = 14
matplotlib.rcParams['figure.figsize'] = (9, 5)
matplotlib.rcParams['figure.facecolor'] = '#00000000'

# %%
schema
# Out:
# Column
# Country                                                  Where do you live?
# Age                       What is your age (in years)? If you prefer not...
# Gender                    Which of the following describe you, if any? P...
# EdLevel                   Which of the following best describes the high...
# UndergradMajor                        What was your primary field of study?
# Hobbyist                                            Do you code as a hobby?
# Age1stCode                At what age did you write your first line of c...
# YearsCode                 Including any education, how many years have y...
# YearsCodePro              NOT including education, how many years have y...
# LanguageWorkedWith        Which programming, scripting, and markup langu...
# LanguageDesireNextYear    Which programming, scripting, and markup langu...
# NEWLearn                  How frequently do you learn a new language or ...
# ...

# %%
schema.Country
# Out:
# 'Where do you live?'

# %%
survey_df.Country
# Out:
# 0                   Germany
# 1            United Kingdom
# 2        Russian Federation
# 3                   Albania
# 4             United States
#                 ...
# 64456         United States
# 64457               Morocco
# 64458              Viet Nam
# 64459                Poland
# 64460                 Spain
# Name: Country, Length: 64306, dtype: object

# %%
survey_df.Country.unique()
# Out:
# array(['Germany', 'United Kingdom', 'Russian Federation', 'Albania',
#        'United States', 'India', 'Tunisia', 'Spain', 'Netherlands',
#        'France', 'Belgium', 'Portugal', 'Canada', 'China', 'Ukraine',
#        'Italy', 'Brazil', 'Austria', 'Mexico', 'Sweden', 'Poland',
#        'Indonesia', 'Greece', 'Israel', 'Czech Republic', nan,
#        'Bosnia and Herzegovina', 'Bulgaria', 'Serbia', 'Switzerland',
#        'Hungary', 'Nepal', 'Slovenia', 'Uruguay', 'Denmark', 'Pakistan',
#        'Taiwan', 'Romania', 'Finland', 'Costa Rica', 'Nigeria', 'Chile',
#        'Turkey', 'Panama', 'Ireland', 'Estonia', 'Philippines',
#        'Australia', 'Nomadic', 'Peru', 'Cyprus', 'Sri Lanka', 'Kenya',
#        'Norway', 'Iran', 'Croatia', 'Egypt', 'Argentina', 'Ghana',
#        'Latvia', 'Morocco', 'Bangladesh', 'Ecuador', 'Haiti',
#        'Venezuela, Bolivarian Republic of...', 'Colombia', 'Lithuania',
#        'El Salvador', 'Honduras', 'Ethiopia', 'Lebanon', 'Uganda',
# ...

# %%
survey_df.Country.nunique()
# Out:
# 183

# %%
survey_df.Country.value_counts()
# Out:
# Country
# United States          12371
# India                   8364
# United Kingdom          3881
# Germany                 3864
# Canada                  2175
#                        ...
# Nauru                      1
# Lesotho                    1
# Saint Lucia                1
# Antigua and Barbuda        1
# Marshall Islands           1
# Name: count, Length: 183, dtype: int64

# %%
survey_df.Country.value_counts().head(15)
# Out:
# Country
# United States         12371
# India                  8364
# United Kingdom         3881
# Germany                3864
# Canada                 2175
# France                 1884
# Brazil                 1804
# Netherlands            1332
# Poland                 1259
# Australia              1199
# Spain                  1157
# Italy                  1115
# Russian Federation     1085
# Sweden                  879
# Pakistan                802
# Name: count, dtype: int64

# %%
top_countries = survey_df.Country.value_counts().head(15)

# %%
top_countries
# Out:
# Country
# United States         12371
# India                  8364
# United Kingdom         3881
# Germany                3864
# Canada                 2175
# France                 1884
# Brazil                 1804
# Netherlands            1332
# Poland                 1259
# Australia              1199
# Spain                  1157
# Italy                  1115
# Russian Federation     1085
# Sweden                  879
# Pakistan                802
# Name: count, dtype: int64

# %%
type(top_countries)
# Out:
# pandas.core.series.Series

# %%
plt.figure(figsize=(14,6))
plt.title(schema.Country)
plt.xticks(rotation=75)
sns.barplot(x=top_countries.index , y=top_countries);

# %%
survey_df.Age
# Out:
# 0         NaN
# 1         NaN
# 2         NaN
# 3        25.0
# 4        31.0
#          ...
# 64456     NaN
# 64457     NaN
# 64458     NaN
# 64459     NaN
# 64460     NaN
# Name: Age, Length: 64306, dtype: float64

# %%
plt.figure(figsize=(14,6))
plt.xlabel('Age')
plt.ylabel('Number of respondents')
plt.title(schema.Age)
plt.hist(survey_df.Age , bins=np.arange(10,80,5) , color='orange');

# %%
survey_df.Gender.value_counts()
# Out:
# Gender
# Man                                                  45895
# Woman                                                 3835
# Non-binary, genderqueer, or gender non-conforming      385
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12,6))
plt.title('Gender Percentage who participated in survey')
plt.xticks(rotation=0)
sns.barplot(x= survey_df.Gender.value_counts().index , y = survey_df.Gender.value_counts());

# %%
plt.figure(figsize=(12,6))
plt.title(schema.Gender)
plt.pie(survey_df.Gender.value_counts() , labels = survey_df.Gender.value_counts().index , autopct = '%1.1f%%', startangle=180);

# %%
schema
# Out:
# Column
# Country                                                  Where do you live?
# Age                       What is your age (in years)? If you prefer not...
# Gender                    Which of the following describe you, if any? P...
# EdLevel                   Which of the following best describes the high...
# UndergradMajor                        What was your primary field of study?
# Hobbyist                                            Do you code as a hobby?
# Age1stCode                At what age did you write your first line of c...
# YearsCode                 Including any education, how many years have y...
# YearsCodePro              NOT including education, how many years have y...
# LanguageWorkedWith        Which programming, scripting, and markup langu...
# LanguageDesireNextYear    Which programming, scripting, and markup langu...
# NEWLearn                  How frequently do you learn a new language or ...
# ...

# %%
survey_df.EdLevel
# Out:
# 0        Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 1           Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2                                                    NaN
# 3        Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 4           Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#                               ...
# 64456    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 64457                                                NaN
# 64458                          Primary/elementary school
# 64459                                                NaN
# 64460         Other doctoral degree (Ph.D., Ed.D., etc.)
# Name: EdLevel, Length: 64306, dtype: object

# %%
survey_df.EdLevel.unique()
# Out:
# array(['Master’s degree (M.A., M.S., M.Eng., MBA, etc.)',
#        'Bachelor’s degree (B.A., B.S., B.Eng., etc.)', nan,
#        'Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)',
#        'Professional degree (JD, MD, etc.)',
#        'Some college/university study without earning a degree',
#        'Associate degree (A.A., A.S., etc.)',
#        'Other doctoral degree (Ph.D., Ed.D., etc.)',
#        'Primary/elementary school',
#        'I never completed any formal education'], dtype=object)

# %%
survey_df.EdLevel.value_counts()
# Out:
# EdLevel
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                          26356
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                                       13024
# Some college/university study without earning a degree                                 7163
# Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)     4724
# Associate degree (A.A., A.S., etc.)                                                    1831
# Other doctoral degree (Ph.D., Ed.D., etc.)                                             1681
# Primary/elementary school                                                               929
# Professional degree (JD, MD, etc.)                                                      793
# I never completed any formal education                                                  480
# Name: count, dtype: int64

# %%
plt.figure(figsize=(20,15))
plt.title(schema.EdLevel)
sns.barplot(x=survey_df.EdLevel.value_counts() , y=survey_df.EdLevel.value_counts().index);

# %%
plt.figure(figsize=(14,10))
plt.xticks(rotation=75);
plt.title(schema.EdLevel);
sns.countplot(y=survey_df.EdLevel);

# %%
survey_df.UndergradMajor.value_counts()
# Out:
# UndergradMajor
# Computer science, computer engineering, or software engineering                   31353
# Another engineering discipline (such as civil, electrical, mechanical, etc.)       4735
# Information systems, information technology, or system administration              4041
# A natural science (such as biology, chemistry, physics, etc.)                      2185
# Mathematics or statistics                                                          1836
# Web development or web design                                                      1773
# A business discipline (such as accounting, finance, marketing, etc.)               1367
# A humanities discipline (such as literature, history, philosophy, etc.)             997
# A social science (such as anthropology, psychology, political science, etc.)        922
# Fine arts or performing arts (such as graphic design, music, studio art, etc.)      715
# ...

# %%
survey_df.UndergradMajor.count()
# Out:
# 50619

# %%
undergrad_maj__pct = survey_df.UndergradMajor.value_counts() * 100 / survey_df.UndergradMajor.count()

# %%
undergrad_maj__pct
# Out:
# UndergradMajor
# Computer science, computer engineering, or software engineering                   61.939193
# Another engineering discipline (such as civil, electrical, mechanical, etc.)       9.354195
# Information systems, information technology, or system administration              7.983168
# A natural science (such as biology, chemistry, physics, etc.)                      4.316561
# Mathematics or statistics                                                          3.627097
# Web development or web design                                                      3.502637
# A business discipline (such as accounting, finance, marketing, etc.)               2.700567
# A humanities discipline (such as literature, history, philosophy, etc.)            1.969616
# A social science (such as anthropology, psychology, political science, etc.)       1.821450
# Fine arts or performing arts (such as graphic design, music, studio art, etc.)     1.412513
# ...

# %%
plt.figure(figsize=(14,10))
sns.barplot(y=undergrad_maj__pct.index , x = undergrad_maj__pct);
plt.title(schema.UndergradMajor);
plt.xlabel('Percentage')
# Out:
# Text(0.5, 0, 'Percentage')

# %%
schema
# Out:
# Column
# Country                                                  Where do you live?
# Age                       What is your age (in years)? If you prefer not...
# Gender                    Which of the following describe you, if any? P...
# EdLevel                   Which of the following best describes the high...
# UndergradMajor                        What was your primary field of study?
# Hobbyist                                            Do you code as a hobby?
# Age1stCode                At what age did you write your first line of c...
# YearsCode                 Including any education, how many years have y...
# YearsCodePro              NOT including education, how many years have y...
# LanguageWorkedWith        Which programming, scripting, and markup langu...
# LanguageDesireNextYear    Which programming, scripting, and markup langu...
# NEWLearn                  How frequently do you learn a new language or ...
# ...

# %%
schema.Employment
# Out:
# 'Which of the following best describes your current employment status?'

# %%
employment_pct = survey_df.Employment.value_counts() * 100 / survey_df.Employment.count()

# %%
employment_pct
# Out:
# Employment
# Employed full-time                                      70.918383
# Student                                                 12.199893
# Independent contractor, freelancer, or self-employed     8.863615
# Not employed, but looking for work                       3.665962
# Employed part-time                                       3.470360
# Not employed, and not looking for work                   0.501625
# Retired                                                  0.380162
# Name: count, dtype: float64

# %%
plt.figure(figsize=(14,10))
sns.barplot(y=employment_pct.index , x = employment_pct);
plt.title(schema.Employment);
plt.xlabel('Percentage')
# Out:
# Text(0.5, 0, 'Percentage')

# %%
survey_df
# Out:
#                   Country   Age Gender  \
# 0                 Germany   NaN    Man
# 1          United Kingdom   NaN    NaN
# 2      Russian Federation   NaN    NaN
# 3                 Albania  25.0    Man
# 4           United States  31.0    Man
# ...                   ...   ...    ...
# 64456       United States   NaN    NaN
# 64457             Morocco   NaN    NaN
# 64458            Viet Nam   NaN    NaN
# 64459              Poland   NaN    NaN
# 64460               Spain   NaN    NaN
#
#                                                EdLevel  \
# 0      Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 1         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2                                                  NaN
# 3      Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 4         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# ...                                                ...
# 64456  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# ...

# %%
survey_below_18_df = survey_df[survey_df.Age <= 18]

# %%
survey_below_18_df
# Out:
#              Country   Age                                             Gender  \
# 28           Ukraine  18.0                                                Man
# 34     United States  16.0                                              Woman
# 52     United States  17.0                                                Man
# 80     United States  18.0                                                Man
# 162    United States  18.0                                                Man
# ...              ...   ...                                                ...
# 64272    Switzerland  18.0                                                Man
# 64362        Algeria  15.0                                                Man
# 64406         Jordan  17.0                                                Man
# 64421     Costa Rica  17.0  Non-binary, genderqueer, or gender non-conforming
# 64441         Canada  17.0                                                Man
#
# ...

# %%
survey_below_18_df.Country.value_counts()
# Out:
# Country
# United States                           348
# India                                   176
# Germany                                 136
# United Kingdom                          117
# France                                   52
#                                        ...
# Venezuela, Bolivarian Republic of...      1
# Rwanda                                    1
# Belize                                    1
# Uzbekistan                                1
# Mauritius                                 1
# Name: count, Length: 109, dtype: int64

# %%
a = survey_below_18_df.Country.value_counts()[['United States' , 'India' , 'United Kingdom' , 'Canada' , 'France' , 'Brazil' , 'Australia']]

# %%
b = survey_df.Country.value_counts()[['United States' , 'India' , 'United Kingdom' , 'Canada' , 'France' , 'Brazil' , 'Australia']]

# %%
programmer_below_18_pect = a/b * 100

# %%
programmer_below_18_pect
# Out:
# Country
# United States     2.813030
# India             2.104256
# United Kingdom    3.014687
# Canada            2.160920
# France            2.760085
# Brazil            2.161863
# Australia         4.086739
# Name: count, dtype: float64

# %%
plt.figure(figsize=(14,10))
sns.barplot(y=programmer_below_18_pect.index , x = programmer_below_18_pect);
plt.title('Percentage of population below age 18');
plt.xlabel('Percentage')
# Out:
# Text(0.5, 0, 'Percentage')

# %%
survey_df.DevType.value_counts()
# Out:
# DevType
# Developer, full-stack                                                                                                                                                           4396
# Developer, back-end                                                                                                                                                             3056
# Developer, back-end;Developer, front-end;Developer, full-stack                                                                                                                  2214
# Developer, back-end;Developer, full-stack                                                                                                                                       1465
# Developer, front-end                                                                                                                                                            1390
# ...

# %%
survey_df.DevType
# Out:
# 0        Developer, desktop or enterprise applications;...
# 1                  Developer, full-stack;Developer, mobile
# 2                                                      NaN
# 3                                                      NaN
# 4                                                      NaN
#                                ...
# 64456                                  Senior executive/VP
# 64457                                                  NaN
# 64458                                                  NaN
# 64459                                                  NaN
# 64460                                                  NaN
# Name: DevType, Length: 64306, dtype: object

# %%
def split_multicolumn(col_series):
    result_df = col_series.to_frame()
    options = []

    for idx, value  in col_series[col_series.notnull()].items():
     
        for option in value.split(';'):
           
            if not option in result_df.columns:
                options.append(option)
                result_df[option] = False
           
            result_df.at[idx, option] = True
    return result_df[options]

# %%
dev_type_df = split_multicolumn(survey_df.DevType)

# %%
dev_type_df
# Out:
#        Developer, desktop or enterprise applications  Developer, full-stack  \
# 0                                               True                   True
# 1                                              False                   True
# 2                                              False                  False
# 3                                              False                  False
# 4                                              False                  False
# ...                                              ...                    ...
# 64456                                          False                  False
# 64457                                          False                  False
# 64458                                          False                  False
# 64459                                          False                  False
# 64460                                          False                  False
#
# ...

# %%
dev_type_totals = dev_type_df.sum().sort_values(ascending=False)

# %%
dev_type_totals
# Out:
# Developer, back-end                              26996
# Developer, full-stack                            26915
# Developer, front-end                             18128
# Developer, desktop or enterprise applications    11687
# Developer, mobile                                 9406
# DevOps specialist                                 5915
# Database administrator                            5658
# Designer                                          5262
# System administrator                              5185
# Developer, embedded applications or devices       4701
# Data or business analyst                          3970
# Data scientist or machine learning specialist     3939
# Developer, QA or test                             3893
# Engineer, data                                    3700
# Academic researcher                               3502
# Educator                                          2895
# Developer, game or graphics                       2751
# ...

# %%
schema.DevType
# Out:
# 'Which of the following describe you? Please select all that apply.'

# %%
plt.figure(figsize=(14,10))
sns.barplot(y=dev_type_totals.index , x = dev_type_totals);
plt.title('Number of people in different tech roles');

# %% [markdown]
# ## What are the most popular programming languages in 2020?

# %%
schema.LanguageWorkedWith
# Out:
# 'Which programming, scripting, and markup languages have you done extensive development work in over the past year, and which do you want to work in over the next year? (If you both worked with the language and want to continue to do so, please check both boxes in that row.)'

# %%
survey_df.LanguageWorkedWith
# Out:
# 0                                   C#;HTML/CSS;JavaScript
# 1                                         JavaScript;Swift
# 2                                 Objective-C;Python;Swift
# 3                                                      NaN
# 4                                        HTML/CSS;Ruby;SQL
#                                ...
# 64456                                                  NaN
# 64457    Assembly;Bash/Shell/PowerShell;C;C#;C++;Dart;G...
# 64458                                                  NaN
# 64459                                             HTML/CSS
# 64460                      C#;HTML/CSS;Java;JavaScript;SQL
# Name: LanguageWorkedWith, Length: 64306, dtype: object

# %%
language_worked_df = split_multicolumn(survey_df.LanguageWorkedWith)

# %%
language_worked_df
# Out:
#           C#  HTML/CSS  JavaScript  Swift  Objective-C  Python   Ruby    SQL  \
# 0       True      True        True  False        False   False  False  False
# 1      False     False        True   True        False   False  False  False
# 2      False     False       False   True         True    True  False  False
# 3      False     False       False  False        False   False  False  False
# 4      False      True       False  False        False   False   True   True
# ...      ...       ...         ...    ...          ...     ...    ...    ...
# 64456  False     False       False  False        False   False  False  False
# 64457   True      True        True   True         True    True   True   True
# 64458  False     False       False  False        False   False  False  False
# 64459  False      True       False  False        False   False  False  False
# 64460   True      True        True  False        False   False  False   True
#
# ...

# %%
language_worked_total = language_worked_df.sum().sort_values(ascending=False)

# %%
language_worked_total
# Out:
# JavaScript               38515
# HTML/CSS                 35884
# SQL                      31153
# Python                   25080
# Java                     22905
# Bash/Shell/PowerShell    18803
# C#                       17879
# PHP                      14874
# TypeScript               14444
# C++                      13578
# C                        12370
# Go                        4989
# Kotlin                    4429
# Ruby                      4006
# Assembly                  3503
# VBA                       3469
# Swift                     3361
# R                         3257
# Rust                      2893
# Objective-C               2317
# Dart                      2262
# Scala                     2026
# Perl                      1773
# Haskell                   1197
# Julia                      503
# dtype: int64

# %%
plt.figure(figsize=(14,10))
sns.barplot(y=language_worked_total.index , x = language_worked_total);
plt.title('Programming Languages worked with');

# %% [markdown]
# ## Which languages are the most people interested to learn over the next year?

# %%
survey_df.LanguageDesireNextYear
# Out:
# 0                                   C#;HTML/CSS;JavaScript
# 1                                             Python;Swift
# 2                                 Objective-C;Python;Swift
# 3                                                      NaN
# 4                                          Java;Ruby;Scala
#                                ...
# 64456                                                  NaN
# 64457    Assembly;Bash/Shell/PowerShell;C;C#;C++;Dart;G...
# 64458                                                  NaN
# 64459                             HTML/CSS;Java;JavaScript
# 64460                      C#;HTML/CSS;Java;JavaScript;SQL
# Name: LanguageDesireNextYear, Length: 64306, dtype: object

# %%
language_desired_next_year_df = split_multicolumn(survey_df.LanguageDesireNextYear)

# %%
language_desired_next_year_df
# Out:
#           C#  HTML/CSS  JavaScript  Python  Swift  Objective-C   Java   Ruby  \
# 0       True      True        True   False  False        False  False  False
# 1      False     False       False    True   True        False  False  False
# 2      False     False       False    True   True         True  False  False
# 3      False     False       False   False  False        False  False  False
# 4      False     False       False   False  False        False   True   True
# ...      ...       ...         ...     ...    ...          ...    ...    ...
# 64456  False     False       False   False  False        False  False  False
# 64457   True      True        True    True   True         True   True   True
# 64458  False     False       False   False  False        False  False  False
# 64459  False      True        True   False  False        False   True  False
# 64460   True      True        True   False  False        False   True  False
#
# ...

# %%
language_desired_next_year_total = language_desired_next_year_df.sum().sort_values(ascending=False)

# %%
language_desired_next_year_total
# Out:
# Python                   26458
# JavaScript               25996
# HTML/CSS                 20596
# SQL                      19806
# TypeScript               17010
# C#                       13542
# Java                     13160
# Go                       12496
# Bash/Shell/PowerShell    11612
# Rust                     10463
# C++                       9655
# Kotlin                    9492
# PHP                       7040
# C                         6019
# Swift                     5590
# Dart                      4700
# R                         4226
# Ruby                      4132
# Scala                     3425
# Haskell                   2954
# Assembly                  2422
# Julia                     1634
# Objective-C               1504
# Perl                      1133
# VBA                       1036
# dtype: int64

# %%
plt.figure(figsize=(14,10))
sns.barplot(y=language_desired_next_year_total.index , x = language_desired_next_year_total);
plt.title('Language People Interested to Learn Next year');

# %%
survey_df
# Out:
#                   Country   Age Gender  \
# 0                 Germany   NaN    Man
# 1          United Kingdom   NaN    NaN
# 2      Russian Federation   NaN    NaN
# 3                 Albania  25.0    Man
# 4           United States  31.0    Man
# ...                   ...   ...    ...
# 64456       United States   NaN    NaN
# 64457             Morocco   NaN    NaN
# 64458            Viet Nam   NaN    NaN
# 64459              Poland   NaN    NaN
# 64460               Spain   NaN    NaN
#
#                                                EdLevel  \
# 0      Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 1         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2                                                  NaN
# 3      Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 4         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# ...                                                ...
# 64456  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# ...

# %%
survey_df.WorkWeekHrs.max()
# Out:
# 140.0

# %% [markdown]
# ## In which countries do developers work the highest number of hours per week? Consider countries with more than 250 responses only.

# %%
survey_df.groupby('Country')

# %%
survey_df
# Out:
#                   Country   Age Gender  \
# 0                 Germany   NaN    Man
# 1          United Kingdom   NaN    NaN
# 2      Russian Federation   NaN    NaN
# 3                 Albania  25.0    Man
# 4           United States  31.0    Man
# ...                   ...   ...    ...
# 64456       United States   NaN    NaN
# 64457             Morocco   NaN    NaN
# 64458            Viet Nam   NaN    NaN
# 64459              Poland   NaN    NaN
# 64460               Spain   NaN    NaN
#
#                                                EdLevel  \
# 0      Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 1         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2                                                  NaN
# 3      Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 4         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# ...                                                ...
# 64456  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# ...

# %%
countries_df = survey_df.groupby('Country')[['WorkWeekHrs']].mean().sort_values( 'WorkWeekHrs' ,ascending=False)

# %%
countries_df.loc[survey_df.Country.value_counts() > 250].head(10)
# Out:
#                WorkWeekHrs
# Country
# Iran             44.337748
# Israel           43.915094
# China            42.150000
# United States    41.802982
# Greece           41.402724
# Viet Nam         41.391667
# South Africa     41.023460
# Turkey           40.982143
# Sri Lanka        40.612245
# New Zealand      40.457551

# %% [markdown]
# ## How important is it to start young to build a career in programming?

# %%
sns.scatterplot(x='Age', y='YearsCodePro', hue='Hobbyist', data=survey_df)
plt.xlabel("Age")
plt.ylabel("Years of professional coding experience");

# %%
sns.scatterplot(x='Age' , y='YearsCodePro' , hue='Hobbyist' , data = survey_df)
plt.xlabel('Age')
plt.ylabel('Years of professional coding experience');

# %%
plt.title(schema.Age1stCode)
sns.histplot(x=survey_df.Age1stCode , bins=30 , kde=True);
